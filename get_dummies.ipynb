# %%
import pandas as pd

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  robot
# 1  human
# 2  human
# 3  robot
# 4  human

# %%
pd.get_dummies(data['whoAmI'])
# Out:
#     human  robot
# 0   False   True
# 1    True  False
# 2    True  False
# 3   False   True
# 4    True  False
# 5   False   True
# 6   False   True
# 7   False   True
# 8   False   True
# 9   False   True
# 10   True  False
# 11  False   True
# 12  False   True
# 13  False   True
# 14   True  False
# 15   True  False
# 16   True  False
# 17   True  False
# 18   True  False
# 19   True  False

# %%
row = data['whoAmI'].unique()

# %%
human = data['whoAmI']=='human' 
robot = data['whoAmI']=='robot'

# %%
data_without_get_dummies = pd.DataFrame(
    {'human': human,
    'robot': robot})

# %%
new_data = pd.DataFrame(data_without_get_dummies)

# %%
new_data
# Out:
#     human  robot
# 0   False   True
# 1    True  False
# 2    True  False
# 3   False   True
# 4    True  False
# 5   False   True
# 6   False   True
# 7   False   True
# 8   False   True
# 9   False   True
# 10   True  False
# 11  False   True
# 12  False   True
# 13  False   True
# 14   True  False
# 15   True  False
# 16   True  False
# 17   True  False
# 18   True  False
# 19   True  False
